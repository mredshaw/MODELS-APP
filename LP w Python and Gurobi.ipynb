# %%
from gurobipy import *

# %%
import os

file_name = "afiro.mps"
current_directory = os.getcwd()
file_path = os.path.join(current_directory, file_name)

if os.path.exists(file_path):
    print(f"File found at {file_path}")
    # Continue with your Gurobi code
else:
    print(f"File not found in the current directory: {current_directory}")
# Out:
# File not found in the current directory: /

# %%
model = read("afiro.mps")
# Out:
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model = read("afiro.mps")
#
# File src/gurobipy/gurobi.pxi:3779, in gurobipy.read()
#
# File src/gurobipy/gurobi.pxi:117, in gurobipy.gurobi.read()
#
# GurobiError: Unable to open file 'afiro.mps' for input

# %%
model.optimize()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.optimize()
#
# NameError: name 'model' is not defined
